# %%
from reddit-etl-job.s

# %%
from google.cloud import bigquery

client = bigquery.Client(project='alex-stocks')

# %%
project_id='alex-stocks'
dataset_id = 'reddit_data'
query = f"""
    SELECT ticker FROM `{project_id}.{dataset_id}.stock_tickers`
    """

query_job = client.query(query)
results = query_job.result()

# %%
import re
tickers = set()
for row in results:
    ticker = row.ticker
    # Double-check that ticker follows our pattern (1-5 letters)
    if re.match(r'^[A-Z]{1,5}$', ticker):
        tickers.add(ticker)

# %%
import yfinance as yf
import pandas as pd
import time
from tqdm.notebook import tqdm

def enrich_with_volume_and_filter_top(stocks, top_n=1000, batch_size=50, delay=1):
    """
    Enrich stock tickers with volume data and filter to top N by volume.
    
    Args:
        stocks (list): List of stock tickers
        top_n (int): Number of top stocks to return by volume
        batch_size (int): Number of stocks to process in each batch
        delay (float): Delay in seconds between batches to respect rate limits
    
    Returns:
        pd.DataFrame: DataFrame with ticker and volume columns, sorted by volume
    """
    enriched_data = []
    
    # Process stocks in batches
    for i in tqdm(range(0, len(stocks), batch_size), desc="Processing batches"):
        batch = stocks[i:i + batch_size]
        
        # Create a single Ticker object for the batch
        tickers_str = " ".join(batch)
        try:
            # Get data for all tickers in batch at once
            data = yf.download(tickers_str, period="1d", group_by='ticker', progress=False)
            
            # Process each ticker in the batch
            for ticker in batch:
                try:
                    if isinstance(data, pd.DataFrame):
                        # Single ticker case
                        volume = data["Volume"].iloc[-1] if not data.empty else 0
                    else:
                        # Multiple tickers case
                        ticker_data = data[ticker]
                        volume = ticker_data["Volume"].iloc[-1] if not ticker_data.empty else 0
                    
                    enriched_data.append({"ticker": ticker, "volume": volume})
                except Exception as e:
                    print(f"Failed to process {ticker}: {str(e)}")
                    enriched_data.append({"ticker": ticker, "volume": 0})
                    
        except Exception as e:
            print(f"Failed to fetch batch starting with {batch[0]}: {str(e)}")
            # Add all tickers from failed batch with 0 volume
            for ticker in batch:
                enriched_data.append({"ticker": ticker, "volume": 0})
        
        # Add delay between batches to respect rate limits
        if i + batch_size < len(stocks):
            time.sleep(delay)
    
    # Convert to DataFrame and sort
    df = pd.DataFrame(enriched_data)
    df = df.sort_values(by="volume", ascending=False).head(top_n)
    return df

# %%
df = enrich_with_volume_and_filter_top(list(tickers))
# Out:
# $HAPS: possibly delisted; no price data found  (period=1d)
# $AFRIW: possibly delisted; no price data found  (period=1d)
# $HSPOR: possibly delisted; no price data found  (period=1d)
# $AFJKU: possibly delisted; no price data found  (period=1d)
# $MLACR: possibly delisted; no price data found  (period=1d)
# $BAYA: possibly delisted; no price data found  (period=1d)
# $LFBE: possibly delisted; no price data found  (period=1d)
# $AGIH: possibly delisted; no price data found  (period=1d)
# $LPBBW: possibly delisted; no price data found  (period=1d)
# $KTTAW: possibly delisted; no price data found  (period=1d)
# $CCIXW: possibly delisted; no price data found  (period=1d)
# $CLNR: possibly delisted; no price data found  (period=1d)
# $SVCCU: possibly delisted; no price data found  (period=1d)
# $GGROW: possibly delisted; no price data found  (period=1d)
# $FLDZ: possibly delisted; no price data found  (period=1d)
# $BHYB: possibly delisted; no price data found  (period=1d)
# $RNWZ: possibly delisted; no price data found  (period=1d)
# $CAPTW: possibly delisted; no price data found  (period=1d)
# $SIMA: possibly delisted; no price data found  (period=1d)
# $MLDR: possibly delisted; no price data found  (period=1d)
# $ZSC: possibly delisted; no price data found  (period=1d)
# $OCTP: possibly delisted; no price data found  (period=1d)
# $ONFOW: possibly delisted; no price data found  (period=1d)
# Failed to fetch data for EMCGR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for XBIT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for MSBIP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SPCY: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for EM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BWET: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for LFT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for NMZ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SLYG: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for VCSH: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FORL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for OXLCL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for DFVX: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PAVMZ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for DOUG: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FTGC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for STBA: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FOXX: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ARDC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for JSPRW: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CNQ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FDVL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ORKT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SMCF: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for NVT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for HPQ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CAKE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for TLTI: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for NNOV: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for HUBS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BCYC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PCVX: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for UTMD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CANG: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for LPRE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for MSB: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CCM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for KGEI: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BBRE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for DEXC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GPRF: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PROK: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BHR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SAGE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FLXR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for QNTM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BPMC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for UNP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BB: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FNF: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PBW: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for RISR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BIIB: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for TDUP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FWRD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BTM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GMHS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for QFLR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BSX: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GUTS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PCLA: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CRDO: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PSTV: Too Many Requests. Rate limited. Try after a while.
# $SVA: possibly delisted; no price data found  (period=1d)
# $ASPCR: possibly delisted; no price data found  (period=1d)
# $RANGR: possibly delisted; no price data found  (period=1d)
# $ZSB: possibly delisted; no price data found  (period=1d)
# $LFDR: possibly delisted; no price data found  (period=1d)
# $MAYAU: possibly delisted; no price data found  (period=1d)
# $RELIW: possibly delisted; no price data found  (period=1d)
# $ISRLU: possibly delisted; no price data found  (period=1d)
# $DRAI: possibly delisted; no price data found  (period=1d)
# Failed to fetch data for VLLU: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for RSBY: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for WAT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for OMH: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for UFI: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SLDR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for KMLM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PDYN: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for NSYS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CLMB: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for LIVE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CTXR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BHST: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ESTA: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for WING: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ABFL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for IWR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PRPO: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CTRN: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for TDC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CFBK: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for TATT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SIZE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for LFWD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for STXK: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for IRBT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CHKP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for MMTM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for KROP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PTBD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for MRVL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CLSM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for IBHG: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for INSW: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for EURKU: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GGLS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PAGP: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ITEQ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SAZ: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CASH: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for VYGR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FSLD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SMAY: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for VSCO: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FUL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for NHI: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SPXC: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CGSM: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for IDAT: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ISVL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for PYPD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for USL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ALDFW: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for GDEV: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for CHARU: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for QMMY: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for MBB: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for FTEL: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SNN: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ATGE: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ODD: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BCTXW: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for BEAGR: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for EVLN: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for ASHS: Too Many Requests. Rate limited. Try after a while.
# Failed to fetch data for SBFG: Too Many Requests. Rate limited. Try after a while.
# $KVACU: possibly delisted; no price data found  (period=1d)
# $DECAU: possibly delisted; no price data found  (period=1d)
# $LIBD: possibly delisted; no price data found  (period=1d)
# $EFFE: possibly delisted; no price data found  (period=1d)
